# %%
import pandas as pd
import duckdb       #SQL
import os
from pathlib import Path #automatically handles file paths across different operating systems
import xlrd         #EXCEL
import pyreadstat   #SPSS

# %% [markdown]
# # VDEM Data

# %%
data_folder = Path(r"../data/raw/VDEM")
vdem_file_path = data_folder /"V-Dem-CY-Full+Others-v16.csv"

# %%
vdem_df = pd.read_csv(vdem_file_path, nrows=3)
print(vdem_df.columns.tolist())
# Out:
# ['country_name', 'country_text_id', 'country_id', 'year', 'historical_date', 'project', 'historical', 'histname', 'codingstart', 'codingend', 'codingstart_contemp', 'codingend_contemp', 'codingstart_hist', 'codingend_hist', 'gapstart1', 'gapstart2', 'gapstart3', 'gapend1', 'gapend2', 'gapend3', 'gap_index', 'COWcode', 'v2x_polyarchy', 'v2x_polyarchy_codelow', 'v2x_polyarchy_codehigh', 'v2x_polyarchy_sd', 'v2x_libdem', 'v2x_libdem_codelow', 'v2x_libdem_codehigh', 'v2x_libdem_sd', 'v2x_partipdem', 'v2x_partipdem_codelow', 'v2x_partipdem_codehigh', 'v2x_partipdem_sd', 'v2x_delibdem', 'v2x_delibdem_codelow', 'v2x_delibdem_codehigh', 'v2x_delibdem_sd', 'v2x_egaldem', 'v2x_egaldem_codelow', 'v2x_egaldem_codehigh', 'v2x_egaldem_sd', 'v2x_api', 'v2x_api_codelow', 'v2x_api_codehigh', 'v2x_api_sd', 'v2x_mpi', 'v2x_mpi_codelow', 'v2x_mpi_codehigh', 'v2x_mpi_sd', 'v2x_freexp_altinf', 'v2x_freexp_altinf_codelow', 'v2x_freexp_altinf_codehigh', 'v2x_freexp_altinf_sd', 'v2x_frassoc_thick', 'v2x_fras
# ...

# %% [markdown]
# Important Columns from VDEM are:
# V-Dem-CY-Full+Others-v16.csv
# monadic:
#
# v2x_cspart
# (Civil Society Participation)
#
# v2x_clphy
# (Physical Integrity Rights)
#
# v2x_freexp_altinf
# (Freedom of Expression & Alternative Info)
#
# v2xcl_rol
# (Rule of Law Index)
#
# v2x_execorr
# (Executive Corruption Index)
#
# v2x_corr
# (Political Corruption Index)
#
# v2xlg_legcon
# (Legislative Constraints on the Executive)
#
# v2x_jucon
# (Judicial Constraints on the Executive)
#
# v2x_regime
# (Regimes of the World)
#
# v2x_egaldem
# (Egalitarian Democracy Index)
#
# v2x_delibdem
# (Deliberative Democracy Index)
#
# v2x_partipdem
# (Participatory Democracy Index)
#
# v2x_libdem
# (Liberal Democracy Index)
#
# v2x_polyarchy
# (Electoral Democracy Index) (Must-Have)
#
# COWcode
#
# ountry_name
#
# year
#
# country_text_id

# %% [markdown]
# # Polity 5 Data

# %%
polity_folder_path = Path(r"../data/raw/PolityV")
polity_file_path = polity_folder_path /"CSPCoupsAnnualv2021.xls"

# %%
polity_excel = pd.ExcelFile(polity_file_path)
print(polity_excel.sheet_names)
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
polity_df1 = pd.read_excel(polity_excel, sheet_name='Sheet1')
print(polity_df1.columns.tolist())
# Out:
# ['ccode', 'scode', 'country', 'year', 'scoup1', 'atcoup2', 'pcoup3', 'apcoup4', 'agcoup', 'foroutex', 'reboutex', 'assassex', 'resignex']

# %% [markdown]
# ‼️‼️Columns?

# %% [markdown]
# Sheet2 and Sheet3 are empty

# %%
p5v_file_path = polity_folder_path/ "p5v2018.sav"

# %%
p5v_df, meta = pyreadstat.read_sav(p5v_file_path)
print(p5v_df.columns.tolist())
# Out:
# ['p5', 'cyear', 'ccode', 'scode', 'country', 'year', 'flag', 'fragment', 'democ', 'autoc', 'polity', 'polity2', 'durable', 'xrreg', 'xrcomp', 'xropen', 'xconst', 'parreg', 'parcomp', 'exrec', 'exconst', 'polcomp', 'prior', 'emonth', 'eday', 'eyear', 'eprec', 'interim', 'bmonth', 'bday', 'byear', 'bprec', 'post', 'change', 'd5', 'sf', 'regtrans']

# %% [markdown]
# ‼️‼️Important feature in p5v_df
# Monadic Features:
#
# year,
#
# country,
#
# ccode,
#
# DEMOC,
#
# AUTOC,
#
# Polity2,
#
# Transition and
#
# interregnum
#
# Flag Variables (-66,-77,-88)

# %% [markdown]
# # SPRI

# %%
spri_folder = Path(r"../data/raw/SPRI")
spri_financial_value_file_path = spri_folder / "Financial Values of Arms Exports 1994_2022.xlsx"

# %%
spri_financial_value_excel = pd.ExcelFile(spri_financial_value_file_path) #excel file object
print(spri_financial_value_excel.sheet_names) #list of sheet names
# Out:
# ['Local Currency', 'Current US', 'Constant US']

# %% [markdown]
# This file not requried for me.

# %%
spri_milex_file_path = spri_folder / "SIPRI_Milex_data_1949_2025_v1.2.xlsx"

# %%
spri_milex_excel = pd.ExcelFile(spri_milex_file_path)
print(spri_milex_excel.sheet_names)
# Out:
# ['Front page', 'Regional totals', 'Local currency financial years', 'Local currency calendar years', 'Constant (2024) US$', 'Current US$', 'Share of GDP', 'Per capita', 'Share of Govt. spending', 'Footnotes']

# %% [markdown]
# Important Sheets:
#
# 1. Constant (2024) US$
#
# 2. Share of GDP
#
# 3. Share of Govt. spending

# %%
spri_milex_df1 = pd.read_excel(spri_milex_excel, sheet_name="Current US$", skiprows=5) #true data starts at row 6
spri_milex_df1.head(10)
# Out:
#               Country  Notes 1949 1950 1951 1952 1953 1954 1955       1956  \
# 0                 NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN        NaN
# 1              Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN        NaN
# 2        North Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN        NaN
# 3             Algeria     §4  xxx  xxx  xxx  xxx  xxx  xxx  xxx        xxx
# 4               Libya  ‡§¶16  xxx  xxx  ...  ...  ...  ...  ...        ...
# 5             Morocco    §17  xxx  xxx  xxx  xxx  xxx  xxx  xxx  23.714286
# 6             Tunisia    NaN  xxx  xxx  xxx  xxx  xxx  xxx  xxx   3.714286
# 7  sub-Saharan Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN        NaN
# 8              Angola    §‖1  xxx  xxx  xxx  xxx  xxx  xxx  xxx        xxx
# 9               Benin      §  xxx  xxx  xxx  xxx  xxx  xxx  xxx        xxx
#
#    ...         2016          2017         2018          2019         2020  \
# ...

# %% [markdown]
# I can remove notes

# %% [markdown]
# Countries are listed under Regions and Sub-regions. I'll remove those regions and subregios.

# %%
spri_milex_df2 = pd.read_excel(spri_milex_excel, sheet_name="Share of GDP", skiprows =5) #true data starts at row 6
spri_milex_df2.head(10)
# Out:
#               Country  Notes 1949 1950 1951 1952 1953 1954 1955      1956  \
# 0                 NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 1              Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 2        North Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 3             Algeria     §4  xxx  xxx  xxx  xxx  xxx  xxx  xxx       xxx
# 4               Libya  ‡§¶16  xxx  xxx  ...  ...  ...  ...  ...       ...
# 5             Morocco    §17  xxx  xxx  xxx  xxx  xxx  xxx  xxx  0.011807
# 6             Tunisia    NaN  xxx  xxx  xxx  xxx  xxx  xxx  xxx       ...
# 7  sub-Saharan Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 8              Angola    §‖1  xxx  xxx  xxx  xxx  xxx  xxx  xxx       xxx
# 9               Benin      §  xxx  xxx  xxx  xxx  xxx  xxx  xxx       xxx
#
#    ...      2016      2017      2018      2019      2020      2021      2022  \
# ...

# %% [markdown]
# I can remove Notes

# %%
spri_milex_df3 = pd.read_excel(spri_milex_excel, sheet_name="Share of Govt. spending", skiprows=7) #true data starts at row 6
spri_milex_df3.head(10)
# Out:
#               Country  Notes  Reporting year 1988      1989      1990  \
# 0                 NaN    NaN             NaN  NaN       NaN       NaN
# 1              Africa    NaN             NaN  NaN       NaN       NaN
# 2        North Africa    NaN             NaN  NaN       NaN       NaN
# 3             Algeria     §4             NaN  ...       ...  0.057841
# 4               Libya  ‡§¶16             NaN  ...       ...       ...
# 5             Morocco    §17             NaN  ...       ...  0.145002
# 6             Tunisia    NaN             NaN  ...       ...       ...
# 7  sub-Saharan Africa    NaN             NaN  NaN       NaN       NaN
# 8              Angola    §‖1             NaN  ...       ...       ...
# 9               Benin      §             NaN  ...  0.104652  0.092393
#
#        1991      1992      1993      1994  ...      2016      2017      2018  \
# 0       NaN       NaN       NaN       NaN  ...       NaN       NaN       NaN
# ...

# %% [markdown]
# I can remove Notes and Reporting Year

# %% [markdown]
# # UCDP

# %%
ucdp_folder = Path(r"../data/raw/UCDP")
ucdp_file_path = ucdp_folder / "UcdpPrioConflict_v26_1.csv"

# %%
ucdp_df = pd.read_csv(ucdp_file_path, nrows=3)
print(ucdp_df.columns.tolist())
# Out:
# ['conflict_id', 'location', 'side_a', 'side_a_id', 'side_a_2nd', 'side_b', 'side_b_id', 'side_b_2nd', 'incompatibility', 'territory_name', 'year', 'intensity_level', 'cumulative_intensity', 'type_of_conflict', 'start_date', 'start_prec', 'start_date2', 'start_prec2', 'ep_end', 'ep_end_date', 'ep_end_prec', 'gwno_a', 'gwno_a_2nd', 'gwno_b', 'gwno_b_2nd', 'gwno_loc', 'region', 'version']

# %% [markdown]
# important feature:
# ### Dyadic:
# side_a,
#
# side_a_id,
#
# sida_a_2nd,
#
# side_b,
#
# side_b_id,
#
# side_b_2nd,
#
# intensity_level,
#
# incompatibility,
#
# territory_name,
#
# type_of_conflict,
#
#  start_date,
#
#  gwno_a,
#
#  gwno_a_2nd,
#
#  gwno_b,
#
#  gwno_b_2nd,
#
#  region.
#
# ### Missing Data:
# dyad_id, conflict_id, year, cumulative_intensity.

# %% [markdown]
# # WDI

# %%
wdi_folder_path = Path(r"../data/raw/WDI_CSV")
wdi_country_file_path = wdi_folder_path/ "WDICountry.csv"
wdi_csv_file_path = wdi_folder_path/ "WDICSV.csv"

# %%
wdi_country_df = pd.read_csv(wdi_country_file_path, nrows=3)
print(wdi_country_df.columns.tolist())
# Out:
# ['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code', 'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code', 'National accounts base year', 'National accounts reference year', 'SNA price valuation', 'Lending category', 'Other groups', 'System of National Accounts', 'Alternative conversion factor', 'PPP survey year', 'Balance of Payments Manual in use', 'External debt Reporting status', 'System of trade', 'Government Accounting concept', 'IMF data dissemination standard', 'Latest population census', 'Latest household survey', 'Source of most recent Income and expenditure data', 'Vital registration complete', 'Latest agricultural census', 'Latest industrial data', 'Latest trade data', 'Latest water withdrawal data']

# %% [markdown]
# Important features:
#
# Country Code,
#
# Long Name,
#
# Income Group

# %%
wdi_csv_df = pd.read_csv(wdi_csv_file_path, nrows=3)
print(wdi_csv_df.columns.tolist())
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']

# %% [markdown]
# Features:
#
# Country Name,
#
# Country Code,
#
#  Indicator Name,
#
#  Indicator Code,
#
#   Year (2000, 2021)

# %% [markdown]
# ### Most important World Bank's indicator codes:
#
# NY.ADJ.NNTY.KD.ZG
#
# NY.ADJ.NNTY.KD
#
# NY.ADJ.NNTY.PC.KD.ZG
#
# NY.ADJ.NNTY.PC.KD
#
# NY.ADJ.AEDU.GN.ZS
#
# TX.VAL.AGRI.ZS.UN
#
# MS.MIL.TOTL.TF.ZS
#
# MS.MIL.TOTL.P1
#
# MS.MIL.XPRT.KD
#
# MS.MIL.MPRT.KD
#
# FB.BNK.CAPA.ZS
#
# FD.RES.LIQU.AS.ZS
#
# FB.AST.NPER.ZS
#
# VC.BTL.DETH
#
# GC.DOD.TOTL.GD.ZS
#
# GC.DOD.TOTL.CNAG.PRD.CREL.MT
#
# EG.IMP.CONS.ZS
#
# NY.EXP.CAPM.KN
#
# NE.EXP.GNFS.ZS
#
# NE.EXP.GNFS.KD.ZG
#
# NE.EXP.GNFS.KD
#
# NE.IMP.GNFS.KD
#
# DT.DOD.DECT.GN.ZS
#
# AG.PRD.FOOD.XD
#
# TX.VAL.FOOD.ZS.UN
#
# TM.VAL.FOOD.ZS.UN
#
# BN.KLT.DINV.CD
#
# BX.KLT.DINV.WD.GD.ZS
#
# BM.KLT.DINV.WD.GD.ZS
#
# EG.USE.COMM.FO.ZS
#
# TX.VAL.FUEL.ZS.UN
#
# TM.VAL.FUEL.ZS.UN
#
# NY.GDP.MKTP.KD
#
# NY.GDP.MKTP.KD.ZG
#
# NY.GDP.PCAP.KD
#
# NY.GDP.PCAP.KD.ZG
#
# SI.POV.GINI
#
# NY.GNP.MKTP.KD
#
# NY.GNP.MKTP.KD.ZG
#
# FP.CPI.TOTL.ZG
#
# NY.GDP.DEFL.KD.ZG
#
# NY.GDP.DEFL.KD.ZG.AD
#
# MS.MIL.XPND.GD.ZS
#
# MS.MIL.XPND.ZS
#
# SP.POP.TOTL.FE.INSP.POP.TOTL.MA.IN
#
# SP.POP.TOTL
#
# GB.XPD.RSDV.GD.ZS
#
# SP.POP.SCIE.RD.P6
#
# TM.TAX.MRCH.SM.AR.ZS
#
# TM.TAX.MRCH.SM.FN.ZS
#
# FI.RES.TOTL.DT.ZS
#
# FI.RES.TOTL.CDFI.RES.XGLD.CD
#
# NE.TRD.GNFS.ZS

# %% [markdown]
# # SystemicPeace

# %%
syspeace_folder_path = Path(r"../data/raw/SystemicPeace")
MEPV_file_path = syspeace_folder_path / "MEPV2012ex.xls"

# %%
MEPV_excel = pd.ExcelFile(MEPV_file_path)
print(MEPV_excel.sheet_names)
# Out:
# ['MEPV2012n']

# %% [markdown]
# only one sheel : MEPV2012n

# %%
MEPV_df = pd.read_excel(MEPV_excel)
print(MEPV_df.columns.tolist())
# Out:
# ['SCODE', 'CCODE', 'COUNTRY', 'YEAR', 'IND', 'INTIND', 'INTVIOL', 'INTWAR', 'CIVVIOL', 'CIVWAR', 'ETHVIOL', 'ETHWAR', 'INTTOT', 'CIVTOT', 'ACTOTAL', 'nBORDER', 'TOTINT', 'TOTCIV', 'TOTALAC', 'nINT', 'nCIV', 'nAC', 'REGION', 'nREGION', 'REGINT', 'REGCIV', 'REGAC', 'nRINT', 'nRCIV', 'nRAC', 'NCIVLIST', 'NINTLIST', 'NACLIST']

# %% [markdown]
# Important Features:
#
# MEPV2012ex.xls
#
# Monadic
#
# nRAC,
#
# REGCIV,
#
# REGAC,
#
# nAC,
#
# TOTCIV,
#
# TOTALAC,
#
# INTTOT,
#
# CIVTOT,
#
#  ACTOTAL,
#
#  IND,
#
#  YEAR,
#
#  SCODE

# %% [markdown]
# # Cultural Difference

# %%
cd_folder_path = Path(r"../data/raw/Capdist&Cultural_difference")
capdist_file_path = cd_folder_path / "capdist.csv"
cul_dist_file_path = cd_folder_path / "cultural_distance_PSW2024.csv"

# %%
capdist_df = pd.read_csv(capdist_file_path, nrows=3)
print(capdist_df.columns.tolist())
# Out:
# ['numa', 'ida', 'numb', 'idb', 'kmdist', 'midist']

# %% [markdown]
# Features
#
# numa
#
# ida
#
# numb
#
# idb
#
# kmdist
#
# midist

# %%
cult_dist_df = pd.read_csv(cul_dist_file_path, nrows=3)
print(cult_dist_df.columns.tolist())
# Out:
# ['year', 'countrycode_1', 'countrycode_2', 'cultdist', 'cultdist_std', 'n_questions']

# %% [markdown]
# Features
#
# Year
#
# countrycode_1
#
# countrycode_2
#
# cultdist
